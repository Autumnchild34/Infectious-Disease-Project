# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# Load cleaned data
print("Loading cleaned dataset...")
df = pd.read_csv('cleaned_infectious_disease.csv')
print(f"Dataset shape: {df.shape}")
print("\n" + "="*50 + "\n")

# 1. DESCRIPTIVE STATISTICS
print("1. DESCRIPTIVE STATISTICS")
print("="*30)

# Overall statistics
print("Overall Statistics:")
print(df.describe())

# Disease-specific statistics
print("\nDisease Statistics:")
disease_stats = df.groupby('Disease').agg({
    'Count': ['sum', 'mean', 'std', 'min', 'max'],
    'Rate': ['mean', 'std', 'min', 'max'],
    'Population': 'sum'
}).round(2)
print(disease_stats)
# Out:
# Loading cleaned dataset...
# Dataset shape: (141777, 14)
#
# ==================================================
#
# 1. DESCRIPTIVE STATISTICS
# ==============================
# Overall Statistics:
#                 Year          Count    Population           Rate  \
# count  141777.000000  141777.000000  1.417770e+05  141777.000000
# mean     2007.857678      81.368438  8.299702e+05       6.984715
# std         4.052999    1954.637660  3.452198e+06      44.861027
# min      2001.000000       0.000000  5.330000e+02       0.000000
# 25%      2004.000000       0.000000  2.871500e+04       0.000000
# 50%      2008.000000       0.000000  1.239460e+05       0.000000
# 75%      2011.000000       1.000000  4.119620e+05       0.203000
# max      2014.000000  174557.000000  3.850149e+07    1020.550000
#
#             CI.lower       CI.upper  Calculated_Rate      Rate_Diff  \
# count  141777.000000  141777.000000    141777.000000  141777.000000
# mean        5.726249      28.912777         6.984713       0.000098
# std        41.479404      87.209601        44.861024       0.001116
# min         0.000000       0.010000         0.000000       0.000000
# 25%         0.000000       1.495000         0.000000       0.000000
# 50%         0.000000       5.233000         0.000000       0.000000
# 75%         0.010000      17.814000         0.202944       0.000068
# max       992.007000    1632.966000      1020.549330       0.254522
#
#           Year_Index         Decade
# count  141777.000000  141777.000000
# mean        7.857678    2003.995006
# std         4.052999       4.897975
# min         1.000000    2000.000000
# 25%         4.000000    2000.000000
# 50%         8.000000    2000.000000
# 75%        11.000000    2010.000000
# max        14.000000    2010.000000
#
# Disease Statistics:
#                                 Count                        Rate             \
#                                   sum  mean    std min  max  mean   std  min
# Disease
# Amebiasis                       21598  8.72  39.64   0  571  0.72  2.37  0.0
# Anaplasmosis and Ehrlichiosis     172  0.07   0.47   0   11  0.02  0.26  0.0
# Babesiosis                        112  0.05   0.30   0    6  0.01  0.07  0.0
# Botulism, Foodborne               128  0.05   0.34   0    6  0.01  0.11  0.0
# Botulism, Other                    24  0.01   0.12   0    3  0.00  0.10  0.0
# ...                               ...   ...    ...  ..  ...   ...   ...  ...
# Typhoid Fever, case              4184  1.69   7.31   0  109  0.13  0.41  0.0
# Typhus Fever                     1966  0.79   5.21   0  108  0.01  0.09  0.0
# Varicella Hospitalizations        852  0.96   4.23   0   56  0.07  0.23  0.0
# Vibrio Infection (non-Cholera)   7120  2.87  13.28   0  269  0.30  0.81  0.0
# Yersiniosis                      4220  1.70   7.32   0  110  0.19  0.57  0.0
#
#                                        Population
#                                   max         sum
# Disease
# Amebiasis                       43.71  2051001349
# Anaplasmosis and Ehrlichiosis   11.32  2051001349
# Babesiosis                       2.25  2051001349
# Botulism, Foodborne              4.47  2051001349
# Botulism, Other                  4.45  2051001349
# ...                               ...         ...
# Typhoid Fever, case              6.50  2051001349
# Typhus Fever                     2.16  2051001349
# Varicella Hospitalizations       3.92   757683235
# Vibrio Infection (non-Cholera)  14.70  2051001349
# Yersiniosis                      9.96  2051001349
#
# [65 rows x 10 columns]
